# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('Store-BackUp-2022-12-14_10-55.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22713 entries, 0 to 22712
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     22713 non-null  object
#  1   sku                      22713 non-null  object
#  2   description              6312 non-null   object
#  3   showOnFrontpage          151 non-null    float64
#  4   category1                22575 non-null  object
#  5   category2                1004 non-null   object
#  6   category3                193 non-null    object
#  7   image                    22713 non-null  object
#  8   recommended_price        397 non-null    float64
#  9   quantity                 22204 non-null  float64
#  10  enabled                  22713 non-null  object
#  11  shipping_freight         22713 non-null  float64
#  12  shippingType             22713 non-null  object
#  13  shippingDisabledMethods  859 non-null    object
# ...

# %%
df['description']
# Out:
# 0        <p>Regal Select Interior is a trusted brand th...
# 1        <p>Benjamin Moore's highest-performing 100% ac...
# 2        <p>Regal Select Interior is a trusted brand th...
# 3        <p>Regal Select Interior is a trusted brand th...
# 4        <p>A premium quality, waterborne alkyd paint t...
#                                ...
# 22708    <ul><li>Applies masking paper with masking tap...
# 22709    <ul><li><span class="a-list-item">Cuts masking...
# 22710    <p>Designed for the pro, the 3M™ Cool Flow™ Mu...
# 22711    <p>3M™ Advanced Masking Film is 3M's most flak...
# 22712    <p>3M™ Organic Vapour Cartridge 6001 is NIOSH ...
# Name: description, Length: 22713, dtype: object

# %%
df[df['description'] == 'Nan'][['name','quantity']].head(10)
# Out:
# Empty DataFrame
# Columns: [name, quantity]
# Index: []

# %%
df[df['description'].isnull() == True].head(5)
# Out:
#                            name       sku description  showOnFrontpage  \
# 10           Plywwod Cut 2 Size  PLY2SIZE         NaN            151.0
# 827              Single Key Cut       KEY         NaN              NaN
# 831  PERFORMANCE STAIN BRUSH 3"  PE700304         NaN              NaN
# 832  PERFORMANCE STAIN BRUSH 4"  PE700305         NaN              NaN
# 836    RAMSET HAMMER SHOT HD222     HD222         NaN              NaN
#
#                                      category1  \
# 10                                         NaN
# 827        Hardware & Cabinet Hardware / Locks
# 831  Paint & Stain / Accessories / Brushes E14
# 832  Paint & Stain / Accessories / Brushes E14
# 836                Out of stock / Discontinued
#
#                                              category2 category3  \
# 10                                                 NaN       NaN
# 827  Hardware & Cabinet Hardware / Door Hooks & Har...       NaN
# ...

# %%
df[df['sku']=='5208673']
# Out:
#                                   name      sku  \
# 11280  18" Aluminum Vulcan Snow Shovel  5208673
#
#                                              description  showOnFrontpage  \
# 11280  This Vulcan snow shovel with steel handle will...              NaN
#
#          category1                                     category2  \
# 11280  Winter Sale  Garden & Outdoor / Shovels F2 / Snow Shovels
#
#                            category3  \
# 11280  Garden & Outdoor / Shovels F2
#
#                                                    image  recommended_price  \
# 11280  https://d2j6dbq0eux0bg.cloudfront.net/images/1...              49.99
#
#        quantity  ... shipping_freight    shippingType shippingDisabledMethods  \
# 11280       0.0  ...              0.0  GLOBAL_METHODS                     NaN
#
#       shippingEnabledMethods           upc   brand seo_title seo_description  \
# 11280                    NaN  755625029027  Vulcan       NaN             NaN
#
# ...
